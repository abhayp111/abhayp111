# %% [markdown]
# # Ice-Cream dataset Analysis

# %%
import kagglehub
path = kagglehub.dataset_download("tysonpo/ice-cream-dataset")

# %%
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/abhaypratapsingh/.cache/kagglehub/datasets/tysonpo/ice-cream-dataset/versions/3

# %%
import pandas as pd
from matplotlib import pyplot
import numpy as np
import seaborn as sns
import os
import sys

# %%
print(path)
# Out:
# /Users/abhaypratapsingh/.cache/kagglehub/datasets/tysonpo/ice-cream-dataset/versions/3

# %%
df_product=pd.read_csv('/Users/abhaypratapsingh/.cache/kagglehub/datasets/tysonpo/ice-cream-dataset/versions/3/combined/products.csv')

# %%
print(df_product.shape)
# Out:
# (241, 8)

# %%
df_reviews=pd.read_csv('/Users/abhaypratapsingh/.cache/kagglehub/datasets/tysonpo/ice-cream-dataset/versions/3/combined/reviews.csv')

# %%
df_reviews.shape
# Out:
# (21674, 13)

# %%
df_reviews
# Out:
#          brand         key          author        date  stars  \
# 0           bj        0_bj  Ilovebennjerry  2017-04-15      3
# 1           bj        0_bj   Sweettooth909  2020-01-05      5
# 2           bj        0_bj       LaTanga71  2018-04-26      3
# 3           bj        0_bj      chicago220  2018-01-14      5
# 4           bj        0_bj        Kassidyk  2020-07-24      1
# ...        ...         ...             ...         ...    ...
# 21669  breyers  68_breyers           Randi  2020-04-22      1
# 21670  breyers  68_breyers          Bethie  2020-09-08      1
# 21671  breyers  68_breyers       Nshaw1994  2020-09-09      5
# 21672  breyers  68_breyers         PamelaG  2020-06-01      5
# 21673  breyers  68_breyers         Fanchon  2020-08-22      5
#
#                                           title  helpful_yes  helpful_no  \
# 0                          Not enough brownies!         10.0         3.0
# ...

# %%
df_product
# Out:
#        brand         key                                name  \
# 0         bj        0_bj                 Salted Caramel Core
# 1         bj        1_bj                 Netflix & Chilll'd™
# 2         bj        2_bj                        Chip Happens
# 3         bj        3_bj                             Cannoli
# 4         bj        4_bj                      Gimme S’more!™
# ..       ...         ...                                 ...
# 236  breyers  64_breyers                           CINNABON®
# 237  breyers  65_breyers        CarbSmart™ Caramel Swirl Bar
# 238  breyers  66_breyers             Layered Dessert S'mores
# 239  breyers  67_breyers       Layered Dessert Peach Cobbler
# 240  breyers  68_breyers  Layered Dessert Brownie Cheesecake
#
#                                                subhead  \
# 0    Sweet Cream Ice Cream with Blonde Brownies & a...
# 1    Peanut Butter Ice Cream with Sweet & Salty Pre...
# 2    A Cold Mess of Chocolate Ice Cream with Fudge ...
# ...

# %%
df=pd.read_csv('/Users/abhaypratapsingh/.cache/kagglehub/datasets/tysonpo/ice-cream-dataset/versions/3/hd/')

# %%
df.shape
# Out:
# (21674, 13)

# %%
df=pd.read_csv('/Users/abhaypratapsingh/.cache/kagglehub/datasets/tysonpo/ice-cream-dataset/versions/3/combined/products.csv')

# %%
df.shape
# Out:
# (241, 8)

# %%
df=pd.read_csv('/Users/abhaypratapsingh/.cache/kagglehub/datasets/tysonpo/ice-cream-dataset/versions/3/combined/images/')
